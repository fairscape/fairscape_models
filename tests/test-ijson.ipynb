# %%
# %pip install ijson
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 26.1.2 is available.
# You should consider upgrading via the 'c:\Users\Max\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
# %pip install --upgrade pip
# Out:
# ...
#
#   Attempting uninstall: pip
#     Found existing installation: pip 21.2.3
#   WARNING: The scripts pip.exe, pip3.10.exe and pip3.exe are installed in 'c:\Users\Max\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#     Uninstalling pip-21.2.3:
#       Successfully uninstalled pip-21.2.3
# ...

# %%
import ijson

# read ROCrate
with open("large_file.json", "rb") as f:
	# Extract items from a top-level array iteratively
	for item in ijson.items(f, "item"):
		print(item)
